# %%
from django_pandas.io import read_frame
import pandas as pd
import matplotlib
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from scipy.stats import pearsonr

import os
os.environ['DJANGO_SETTINGS_MODULE'] = 'winesurvey.settings'
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

import django
django.setup()

from survey.models import WineItem, SurveyQuestionResponse, SurveyABTestInstance

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (20.0, 10.0)
plt.rcParams['font.size'] = 15

wine_data = pd.read_csv('data/wineitem_0519_0953.csv')
ab_data = pd.read_csv('data/surveyabtestinstance_0525.csv')
survey_data = pd.read_csv('data/surveyquestionresponse_0525.csv')

# %%
# Constants

WINE_KNOWLEDGE_LABELS = ["", "Literally \nnone at \nall","The basics\n - Cab, \nChardonnay, \nand that's \nabout it","Reasonably \ninformed - \nKnow a \ncouple \nvarietals \nand regions","An \nenthusiast\n - Know my \nspecific taste,\n how to \nroughly pair,\n love learning\n more","A \nconnoisseur -\n friends come\n to me for\n wine knowledge"]
RELEVANT_WINE_COLS = []

MATRIX_QUESTIONS = ['buying_location', 'wine_services', 'learning_sources', 'format_likelihood', 'more_likely']

LABELS_LOOKUP = {
    'buying_location': 'Where do you typically buy your wine?',
    'buying_location[grocery]': 'Grocery Store',
    'buying_location[wine_shop]': 'Wine Shop',
    'buying_location[tasting_room]': 'Tasting Room',
    'buying_location[club_membership]': 'Wine Club Membership',
    'buying_location[online]': 'Online',
    'buying_location[0]': 'Never',
    'buying_location[1]': 'Rarely',
    'buying_location[2]': 'Sometimes',
    'buying_location[3]': 'Typically',
    'buying_location[4]': 'Almost Always',
    'wine_services': 'Would you consider buying wine from any of the following services?',
    'wine_services[0]': "Haven't heard of",
    'wine_services[1]': "Heard of, wouldn't consider",
    'wine_services[2]': "Heard of, would consider",
    'wine_services[3]': "Have tried but no longer use",
    'wine_services[4]': "Am a customer",
    'wine_services[winc]': "Winc",
    'wine_services[nakewines]': "NakedWines",
    'wine_services[vinebox]': "Vinebox",
    'wine_services[nytwineclub]': "New York Times Wine Club",
    'wine_services[blueapron]': "Blue Apron Wine",
    'wine_services[firstleaf]': "First Leaf",
    'wine_services[localshop]': "A local wine shop website",
    'wine_services[wineclub]': "A favorite winery's club",
    'learning_sources': 'How likely would you be to use each of the following sources to learn about new wine brands?',
    'learning_sources[0]': 'Not at all likely',
    'learning_sources[1]': 'Slightly likely',
    'learning_sources[2]': 'Moderately likely',
    'learning_sources[3]': 'Extremely likely',
    'learning_sources[4]': 'Already do',
    'learning_sources[instagram_facebook]': "Instagram or Facebook ads",
    'learning_sources[influencers]': 'Influencers',
    'learning_sources[newsletters]': "Wine newsletters/magazines",
    'learning_sources[wine_clubs]': 'Curated wine clubs',
    'learning_sources[app]': 'Wine app',
    'learning_sources[browsing_aisles]': 'Browsing aisles',
    'learning_sources[browsing_online]': 'Browsing online',
    'format_likelihood': 'How likely would you be to buy the following formats?',
    'format_likelihood[0]': 'Not at all likely',
    'format_likelihood[1]': 'Slightly likely',
    'format_likelihood[2]': 'Moderately likely',
    'format_likelihood[3]': 'Extremely likely',
    'format_likelihood[4]': 'Already do',
    'format_likelihood[individual_bottles_winery]': 'Individual bottles directly from winery website',
    'format_likelihood[individual_bottles_site]': 'Individual bottles from a site',
    'format_likelihood[monthly_nice]': '$90 monthly subscription',
    'format_likelihood[monthly_value]': '$45 monthly subscription',
    'format_likelihood[monthly_glass]': '$90 monthly glass-by-glass subscription',
    'format_likelihood[tasting]': 'Tasting set of mini-bottles',
    'more_likely': 'Would any of the follow make you more likely to order wine online, and how much more likely?',
    'more_likely[0]': 'Less likely',
    'more_likely[1]': 'No influence',
    'more_likely[2]': 'Slightly more likely',
    'more_likely[3]': 'Much more likely',
    'more_likely[4]': 'Sign me up',
    'more_likely[taste_quiz]': 'Tasting profile quiz',
    'more_likely[discount]': '40% discount on first purchase',
    'more_likely[shipping]': 'Free shipping',
    'more_likely[local_producers]': 'Wine from small local producers',
    'more_likely[curated]': 'Expert curated picks',
    'more_likely[rare]': 'Rare or exclusive wines',
    'more_likely[glass]': 'Wines in by-the-glass bottles',
    'more_likely[cans]': 'Wine in cans',
    'more_likely[educational]': 'With educational materials'
    
}

# %% [markdown]
# # Survey Results

# %%
wide_survey_data = survey_data.pivot(index='survey_response_id', columns='survey_question_id', values='answer')
wide_survey_data = wide_survey_data.dropna(subset=['age'])
wide_survey_data = wide_survey_data[wide_survey_data['age'].astype('int') < 38]
wide_survey_data = wide_survey_data.drop(columns=['email'])
wide_survey_data = wide_survey_data.astype('float')
#survey_data
wsd = wide_survey_data
print(len(wsd))
# Out:
# 105

# %%
print("Basic data")

import matplotlib.pyplot as plt

def show_counts_as_bar(series):
    possible_values = [0, 1, 2, 3, 4]
    
    fig, ax = plt.subplots()
    ax.bar(possible_values, [sum(series == val) for val in possible_values])
    
    return ax

ages = wide_survey_data['age'].dropna()
print(ages.mean())
unique_ages = sorted(wide_survey_data['age'].unique())
wine_love = wide_survey_data['wine_love'].astype('int')
wine_knowledge = wsd['wine_knowledge'].astype('int')
avg_bottle_price = wsd['typical_bottle_price']
num_bottles = wsd['bottles_per_month']

fig, ax = plt.subplots()
ax.hist(ages.astype('int'))
ax.set_title("Age of Respondents")
ax.set_ylabel('# of responses')
ax.set_xlabel('Age')

fig, ax = plt.subplots()
ax.scatter(unique_ages, [wide_survey_data[wide_survey_data['age'] == age]['wine_love'].mean() for age in unique_ages])

ax = show_counts_as_bar(wine_love)
ax.set_title("Wine Love")
ax.set_ylabel('# of responses')
ax.set_xticklabels(["","Don't care \nfor it \nat all","Will \noccasionally \nhave a \nglass","Will buy a\n bottle once \nin a \nwhile", "Love a \ngood wine \ntasting","My wine \ncollection \nis a \npoint of \npride"], multialignment="center")

ax = show_counts_as_bar(wine_knowledge)
ax.set_title("Wine Knowledge")
ax.set_ylabel("# of responses")
ax.set_xticklabels(["", "Literally \nnone at \nall","The basics\n - Cab, \nChardonnay, \nand that's \nabout it","Reasonably \ninformed - \nKnow a \ncouple \nvarietals \nand regions","An \nenthusiast\n - Know my \nspecific taste,\n how to \nroughly pair,\n love learning\n more","A \nconnoisseur -\n friends come\n to me for\n wine knowledge"])

fig, ax = plt.subplots()
print(avg_bottle_price.mean())
ax.hist(avg_bottle_price)
ax.set_title("Typical bottle price")
ax.set_ylabel("# of responses")
ax.set_xlabel("Price ($)")

fig, ax = plt.subplots()
print(num_bottles.mean())
ax.hist(num_bottles)
ax.set_title("Number of bottles purchased per month")
ax.set_ylabel("# of responses")
ax.set_xlabel("# of bottle purchased per month")

fig, ax = plt.subplots()
print((avg_bottle_price * num_bottles).mean())
ax.hist(avg_bottle_price * num_bottles, range=[0, 300])
ax.set_title("Total spent per month")
ax.set_ylabel("# of responses")
ax.set_xlabel("Amount spent (calculated as # of bottles x avg bottle price)")
# Out:
# Basic data
# 27.885714285714286
# 19.2399
# 4.480952380952381
# 79.964
# /Users/taylorsavage/repos/wine-survey/env/lib/python3.6/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/taylorsavage/repos/wine-survey/env/lib/python3.6/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# Text(0.5, 0, 'Amount spent (calculated as # of bottles x avg bottle price)')

# %%
print("Simple correlations")

def show_box_by_grouping(data, col_to_group_by, col_to_box):
    fig, ax = plt.subplots()
    
    col_group_values = sorted(data[col_to_group_by].unique())
    
    data_to_plot = [data[data[col_to_group_by] == col_group_value][col_to_box] for col_group_value in col_group_values]
        
    ax.boxplot(data_to_plot)
    ax.set_xticklabels(col_group_values)
    
    return ax

ax = show_box_by_grouping(wsd.dropna(subset=['wine_knowledge', 'typical_bottle_price']), 'wine_knowledge', 'typical_bottle_price')
ax.set_title("Average bottle price by wine knowledge")
ax.set_ylabel("Average bottle price $")
ax.set_xticklabels(["Literally \nnone at \nall","The basics\n - Cab, \nChardonnay, \nand that's \nabout it","Reasonably \ninformed - \nKnow a \ncouple \nvarietals \nand regions","An \nenthusiast\n - Know my \nspecific taste,\n how to \nroughly pair,\n love learning\n more","A \nconnoisseur -\n friends come\n to me for\n wine knowledge"])

ax = show_box_by_grouping(wsd.dropna(subset=['wine_knowledge', 'bottles_per_month']), 'wine_knowledge', 'bottles_per_month')
ax.set_title("Bottles purchased by wine knowledge")
ax.set_ylabel("# bottles purchased per month")
ax.set_xticklabels(["Literally \nnone at \nall","The basics\n - Cab, \nChardonnay, \nand that's \nabout it","Reasonably \ninformed - \nKnow a \ncouple \nvarietals \nand regions","An \nenthusiast\n - Know my \nspecific taste,\n how to \nroughly pair,\n love learning\n more","A \nconnoisseur -\n friends come\n to me for\n wine knowledge"])
# Out:
# Simple correlations
# [Text(0, 0, 'Literally \nnone at \nall'),
#  Text(0, 0, "The basics\n - Cab, \nChardonnay, \nand that's \nabout it"),
#  Text(0, 0, 'Reasonably \ninformed - \nKnow a \ncouple \nvarietals \nand regions'),
#  Text(0, 0, 'An \nenthusiast\n - Know my \nspecific taste,\n how to \nroughly pair,\n love learning\n more'),
#  Text(0, 0, 'A \nconnoisseur -\n friends come\n to me for\n wine knowledge')]

# %%
#DOESN"T MAKE SENSE CURRENTLY, IGNORE

def cols_by_question(data, question_prefix):
    return [col for col in data.columns if question_prefix in col] 


def show_grouped_bar(data, col_to_group_by, cols_to_measure):
    fig, ax = plt.subplots()
    
    data = data.dropna(subset=[col_to_group_by])
    data = data.dropna(subset=cols_to_measure)
    
    potential_values = sorted(pd.unique(data[cols_to_measure].values.ravel()))
    
    width = 1 / (len(cols_to_measure) + 2)
    
    for i, col in enumerate(cols_to_measure):
        vc = data[col].value_counts()
        heights = {val: vc[val] if val in vc else 0 for val in potential_values}
        ax.bar(np.arange(len(potential_values)) - (i - len(cols_to_measure) / 2) * width, [heights[k] for k in sorted(heights.keys())], width=width, align='center', label=col)

    ax.legend(cols_to_measure)
    return ax

ax = show_grouped_bar(wsd, 'wine_knowledge', cols_by_question(wsd, 'more_likely'))
ax.set_xticklabels(WINE_KNOWLEDGE_LABELS)
# Out:
# [Text(0, 0, ''),
#  Text(0, 0, 'Literally \nnone at \nall'),
#  Text(0, 0, "The basics\n - Cab, \nChardonnay, \nand that's \nabout it"),
#  Text(0, 0, 'Reasonably \ninformed - \nKnow a \ncouple \nvarietals \nand regions'),
#  Text(0, 0, 'An \nenthusiast\n - Know my \nspecific taste,\n how to \nroughly pair,\n love learning\n more'),
#  Text(0, 0, 'A \nconnoisseur -\n friends come\n to me for\n wine knowledge')]

# %%
import matplotlib.pyplot as plt
import re

print("Number of responses: %d" % len(wide_survey_data))

def show_matrix_question_results(subset_data, label_addition=""):
    question_prefixes = ['format_likelihood', 'buying_location', 'wine_services', 'more_likely']
    for question in MATRIX_QUESTIONS:
        fig, ax = plt.subplots()

        filtered_data = subset_data.filter(regex=question, axis=1).dropna()
        labels = filtered_data.columns
        potential_values = sorted(pd.unique(filtered_data.values.ravel()))

        x = np.arange(len(potential_values))
        width = 1 / (len(filtered_data.columns) + 2)

        for i, col in enumerate(filtered_data.columns):
            vc = filtered_data[col].value_counts()
            heights = {val: vc[val] if val in vc else 0 for val in potential_values}
            ax.bar(x - (i - len(labels) / 2) * width, [heights[k] for k in sorted(heights.keys())], width=width, align="center", label=LABELS_LOOKUP[col])

        ax.set_ylabel('Count')
        ax.set_title("%s %s" % (LABELS_LOOKUP[question], label_addition))
        ax.set_xticks(x)
        ax.set_xticklabels([LABELS_LOOKUP["%s[%d]" % (question, v)] for v in potential_values])
        ax.legend([LABELS_LOOKUP[col] for col in filtered_data.columns])
        #ax.bar(filtered_data.T, density=False, bins=n_bins, histtype='bar', label=filtered_data.columns)
        #ax.legend()

show_matrix_question_results(wsd)
# Out:
# Number of responses: 105

# %% [markdown]
# ## Clustering Consumers

# %%
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

solid_wsd = wsd.dropna()

dendogram = sch.dendrogram(sch.linkage(solid_wsd, method='ward'))

hc = AgglomerativeClustering(n_clusters=2, affinity='euclidean', linkage='ward')

y_hc = hc.fit_predict(solid_wsd)

print(solid_wsd[y_hc == 1].mean() - solid_wsd[y_hc == 0].mean())

#print(solid_wsd[y_hc == 0].describe())

#print(solid_wsd[y_hc == 1].describe() - solid_wsd[y_hc == 0].describe())
# Out:
# survey_question_id
# age                                              0.600649
# bottles_per_month                                4.312500
# buying_location[club_membership]                 0.316558
# buying_location[grocery]                         0.090909
# buying_location[online]                          0.285714
# buying_location[tasting_room]                    0.155844
# buying_location[wine_shop]                      -0.053571
# format_likelihood[individual_bottles_site]      -0.095779
# format_likelihood[individual_bottles_winery]     0.316558
# format_likelihood[monthly_glass]                 0.097403
# format_likelihood[monthly_nice]                  0.202922
# format_likelihood[monthly_value]                 0.207792
# format_likelihood[tasting]                      -0.246753
# glasses_per_month                               22.090909
# learning_sources[app]                            0.241883
# learning_sources[browsing_aisles]                0.462662
# ...

# %% [markdown]
# ## High-information consumers

# %%
hic = wsd[wsd['wine_knowledge'] > 2]
hic.describe()

show_matrix_question_results(hic, label_addition="[Highly-informed consumers]")

# %% [markdown]
# ## Notes
#
# Ideas:
# * Train a model to predict the outcome of any particular matchup. Matchup vars = A - B, outcome = 1 if A wins 0 if B wins

# %%
valid_wines = wine_data[wine_data['price'] < 100]['item key'].tolist()
valid_ab_data = ab_data[ab_data['winner_id'].isin(valid_wines) & ab_data['loser_id'].isin(valid_wines)]
print(len(valid_ab_data), len(valid_wines))
# Out:
# 1960 167

# %% [markdown]
# # Elo Ratings

# %%
from elosports.elo import Elo
eloLeague = Elo(k = 20, homefield=0)

for w in valid_wines:
    eloLeague.addPlayer(w)
    
for _, ab in valid_ab_data.iterrows():
    if ab['winner_id'] in valid_wines and ab['loser_id'] in valid_wines:
        eloLeague.gameOver(winner=ab['winner_id'], loser=ab['loser_id'], winnerHome=False)

elo = pd.DataFrame(columns = ['item_key', 'elo'])
for team in eloLeague.ratingDict.keys():
    row = {'item_key': team, 'elo': eloLeague.ratingDict[team]}
    elo = elo.append(row, ignore_index=True)
elo = elo.sort_values(by='elo', ascending=False)

data = elo.join(wine_data.set_index('item key'), on='item_key')
data = data.join(ab_data['winner_id'].value_counts(), on='item_key').rename(columns={'winner_id': 'wins'})
data = data.join(ab_data['loser_id'].value_counts(), on='item_key').rename(columns={'loser_id': 'losses'})

expanded_elo_data = pd.get_dummies(data, columns=['label type','region','varietal','vintage'])

xcols = [col for col in expanded_elo_data if col.startswith('label type') or col.startswith('region') or col.startswith('varietal')]
xcols.extend(['price'])

label_type_cols = [col for col in expanded_elo_data if col.startswith('label type')]

relevant_data = data[['item_key', 'elo', 'name', 'description', 'price', 'bottle image url', 'label type', 'region', 'wins', 'losses']]

# %%
expanded_elo_data.describe()
# Out:
#                elo       price  point score  user rating  sale price  \
# count   167.000000  167.000000          0.0    60.000000   61.000000
# mean   1500.000000   28.049880          NaN     3.803333   16.694918
# std      48.756171   17.449307          NaN     0.236476    6.181543
# min    1343.986725    7.990000          NaN     3.300000   12.990000
# 25%    1468.894984   16.990000          NaN     3.600000   12.990000
# 50%    1504.942114   19.990000          NaN     3.800000   12.990000
# 75%    1529.561763   34.490000          NaN     3.900000   16.990000
# max    1633.705266   99.990000          NaN     4.400000   39.990000
#
#        original url  tasting notes  winc product id  winc product code  \
# count           0.0            0.0        61.000000       6.100000e+01
# mean            NaN            NaN     11632.081967       8.333160e+06
# std             NaN            NaN       622.948267       7.097936e+06
# ...

# %%
data[['name', 'description', 'price', 'bottle image url', 'label type', 'region', 'wins', 'losses']].head(10)

from IPython.display import Image
from IPython.core.display import HTML 


data['img_html'] = ["<img src='%s' height='20px'/>" % r['bottle image url'] for _, r in data.iterrows()]

whimsical = data['label type' = 'WH']

HTML(whimsical[['name', 'description', 'price', 'img_html']].head(10).to_html(escape=False))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/repos/wine-survey/env/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-d665ec362888> in <module>
# ...

# %%
data[['item_key', 'elo', 'name', 'description', 'price', 'bottle image url', 'label type', 'region', 'wins', 'losses']].tail(10)
# Out:
#        item_key          elo  \
# 48    winc10616  1426.269426
# 124  wine552180  1421.862171
# 97   wine532576  1420.562646
# 64   wine552206  1407.459428
# 108  wine430133  1398.108201
# 6     winc12271  1398.028654
# 71   wine533848  1379.199860
# 134  wine527517  1372.554741
# 44    winc11749  1372.324446
# 139  wine590147  1343.986725
#
#                                                   name  \
# 48                              2013 Alcalá Monastrell
# 124                          2018 Cakebread Chardonnay
# 97   2015 Silver Oak Alexander Valley Cabernet Sauv...
# 64      2017 Chateau de Beaucastel Chateauneuf-du-Pape
# 108   2014 Heitz Cellar Napa Valley Cabernet Sauvignon
# 6                            2017 TBT White Wine Blend
# 71                              2018 Kris Pinot Grigio
# 134                     2015 Jordan Cabernet Sauvignon
# 44           2015 Compartés x WINC Sparkling Red Blend
# 139               2015 Altesino Brunello di Montalcino
#
# ...

# %%
print("Correlation with elo rating")

c = expanded_elo_data.corr()['elo']


#s = c.unstack()
so = c.sort_values(kind="quicksort")

print("Most positively correlated:")
print(so[so < 1].dropna().tail(20))

print("Most negatively correlated:")
print(so[so < 1].dropna().head(20))
# Out:
# Correlation with elo rating
# Most positively correlated:
# region_Clarksburg             0.096253
# varietal_Chenin Blanc         0.096253
# region_Sancerre               0.096913
# region_California             0.100010
# region_Colchagua Valley       0.103599
# region_Provence               0.104203
# region_Eola-Amity Hills       0.104799
# region_Italy                  0.105020
# varietal_Italian Red Blend    0.105020
# wine product id               0.107279
# region_Lake County            0.114927
# region_Knights Valley         0.119030
# region_Languedoc              0.121134
# region_Vino de Espana         0.138311
# varietal_Tempranillo          0.142901
# varietal_Carmenere            0.143131
# varietal_Sauvignon Blanc      0.193067
# region_Chianti Classico       0.208396
# user rating                   0.222732
# wins                          0.757465
# Name: elo, dtype: float64
# Most negatively correlated:
# losses                         -0.824022
# ...

# %% [markdown]
# ## Price

# %%
ax = expanded_elo_data.plot.scatter(x='price', y='elo')
ax.set_title("Wine Price vs. Wine Elo rating")
# Out:
# Text(0.5, 1.0, 'Wine Price vs. Wine Elo rating')

# %%
expanded_elo_data.hist('price', bins=25)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12cf76278>]],
#       dtype=object)

# %%
from sklearn.model_selection import train_test_split
from sklearn import linear_model
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score

train, test = train_test_split(expanded_elo_data, test_size=0.2)

x_train = train[label_type_cols]
y_train = train['elo'].values.reshape(-1,1)

x_test = test[label_type_cols]
y_test = test['elo'].values.reshape(-1,1)

regr = linear_model.LinearRegression()
regr.fit(x_train, y_train)

y_pred = regr.predict(x_test)

print('Coefficients: \n', regr.coef_)
print('MSE: %.2f' % mean_squared_error(y_test, y_pred))
print('r2: %.2f' % r2_score(y_test, y_pred))

plt.scatter(x_test, y_test, color='black')
plt.plot(x_test, y_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# Coefficients:
#  [[-1.91903701e+16 -1.91903701e+16 -1.91903701e+16 -1.91903701e+16]]
# MSE: 2638.08
# r2: -0.20
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-9d090cc9af02> in <module>
#      21 print('r2: %.2f' % r2_score(y_test, y_pred))
#      22
# ---> 23 plt.scatter(x_test, y_test, color='black')
#      24 plt.plot(x_test, y_pred, color='blue', linewidth=3)
#      25
#
# ~/repos/wine-survey/env/lib/python3.6/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2814         verts=verts, edgecolors=edgecolors,
#    2815         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2816         None else {}), **kwargs)
#    2817     sci(__ret)
#    2818     return __ret
#
# ...

# %%
elo.head(5)
#elo.groupby('varietal').mean()
pearsonr(elo['price'], elo['elo'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/repos/wine-survey/env/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-be3fbc5e6af0> in <module>
#       1 elo.head(5)
# ...

# %% [markdown]
# ## Matchup Predictor

# %%
from sklearn import preprocessing

matchups_df = valid_ab_data.join(wine_data.set_index('item key').add_prefix('winner_'), 
                           on='winner_id')
matchups_df = matchups_df.join(wine_data.set_index('item key').add_prefix('loser_'),
                              on='loser_id')

matchups_df['winner_source'] = ["winc" if row['winner_id'].startswith('winc') else 'wine' for _, row in matchups_df.iterrows()]
matchups_df['loser_source'] = ["wine" if row['loser_id'].startswith('wine') else 'winc' for _, row in matchups_df.iterrows()]
matchups_df['winner_A'] = matchups_df['item_A_id'] == matchups_df['winner_id']

n = len(matchups_df)
winc_wine_competitive_matchups = matchups_df[matchups_df['winner_source'] != matchups_df['loser_source']]

# %%
print("Does it make a different whether a wine is A or B?")

from scipy import stats

p = stats.binom_test(sum(matchups_df['winner_A']), n=n, p=0.5)

print("According to the binomial test, p=%.2f" % p)
# Out:
# Does it make a different whether a wine is A or B?
# According to the binomial test, p=0.57

# %%
print("Is winc.com more likely to win than wine.com?")


p = stats.binom_test(sum(winc_wine_competitive_matchups['winner_source'] == 'winc'), n=len(winc_wine_competitive_matchups))

print("According to the binomial test, p=%.2f" % p)
# Out:
# Is winc.com more likely to win than wine.com?
# According to the binomial test, p=0.24

# %%
print("Are cheaper wines more likely to win?")

price_diff = matchups_df['winner_price'] - matchups_df['loser_price']

ax = price_diff.hist(density=True)
ax.set_title("Price Differential")
ax.set_xlabel("winner price - loser price")
ax.set_ylabel("% of matchups")

t, p = stats.ttest_1samp(price_diff.to_numpy(), 0.0)

print("According to the 1-sample T test, p=%.2f t=%.2f" % (p, t))
# Out:
# Are cheaper wines more likely to win?
# According to the 1-sample T test, p=0.00 t=-6.80

# %%
print("Which label types are most likely to win?")

winner_label_type = matchups_df['winner_label type'].value_counts()
loser_label_type = matchups_df['loser_label type'].value_counts()

print((winner_label_type) / (winner_label_type + loser_label_type))

wine_data.groupby(['label type'])['price'].mean()
# Out:
# Which label types are most likely to win?
# MI    0.518310
# MO    0.513406
# TR    0.510840
# WH    0.466728
# dtype: float64
# label type
# MI    28.523333
# MO    36.685652
# TR    42.853636
# WH    36.781667
# Name: price, dtype: float64

# %%
matchups_df.columns
# Out:
# Index(['ID', 'survey_response_id', 'created', 'item_A_id', 'item_B_id',
#        'winner_id', 'loser_id', 'winner_name', 'winner_description',
#        'winner_price', 'winner_bottle image url', 'winner_label type',
#        'winner_closure type', 'winner_country', 'winner_region',
#        'winner_origin', 'winner_wine type', 'winner_varietal',
#        'winner_vintage', 'winner_point score', 'winner_story',
#        'winner_user rating', 'winner_sale price', 'winner_original url',
#        'winner_tasting notes', 'winner_winc product id',
#        'winner_winc product code', 'winner_wine product id', 'loser_name',
#        'loser_description', 'loser_price', 'loser_bottle image url',
#        'loser_label type', 'loser_closure type', 'loser_country',
#        'loser_region', 'loser_origin', 'loser_wine type', 'loser_varietal',
#        'loser_vintage', 'loser_point score', 'loser_story',
#        'loser_user rating', 'loser_sale price', 'loser_original url',
# ...

# %%
matchups_df['winner_vintage']
# Out:
# 0          NaN
# 2          NaN
# 3       2012.0
# 4          NaN
# 5          NaN
#          ...
# 2140       NaN
# 2141    2012.0
# 2142       NaN
# 2143       NaN
# 2144       NaN
# Name: winner_vintage, Length: 1960, dtype: float64

# %%
ml_wine_data = wine_data.set_index('item key')[['name', 'description', 'price', 'varietal', 'region', 'wine type', 'label type']]
ml_matchups = valid_ab_data.join(ml_wine_data.add_prefix('A_'), 
                           on='item_A_id')
ml_matchups = ml_matchups.join(ml_wine_data.add_prefix('B_'),
                              on='item_B_id')

ml_matchups['A_source'] = ["winc" if row['item_A_id'].startswith('winc') else 'wine' for _, row in ml_matchups.iterrows()]
ml_matchups['B_source'] = ["wine" if row['item_B_id'].startswith('wine') else 'winc' for _, row in ml_matchups.iterrows()]
ml_matchups['winner_A'] = ml_matchups['item_A_id'] == ml_matchups['winner_id']

# Doing some feature engineering
ml_matchups['A_desc_length'] = [len(row['A_description']) for _, row in ml_matchups.iterrows()]
ml_matchups['B_desc_length'] = [len(row['B_description']) for _, row in ml_matchups.iterrows()]

ml_matchups = pd.get_dummies(ml_matchups, columns=['A_region', 'B_region', 'A_wine type', 'B_wine type', 'A_varietal', 'B_varietal', 'A_label type', 'B_label type'])

matchups_xcols = [col for col in ml_matchups if 'label type' in col or 'region' in col or 'varietal' in col or 'price' in col]

# %%
# Set up the training and test datasets to try to build matchup predictions
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

train, test = train_test_split(ml_matchups, test_size=0.2)

train_X = train[matchups_xcols]
train_Y = train['winner_A']

test_X = test[matchups_xcols]
test_Y = test['winner_A']

# %%
gnb = GaussianNB()
model = gnb.fit(train_X, train_Y)

preds = gnb.predict(test_X)

print(accuracy_score(test_Y, preds))
# Out:
# 0.5688775510204082

# %%
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(alpha=1, max_iter=1000)
clf = mlp.fit(train_X, train_Y)
preds = clf.predict(test_X)
print(clf.score(test_X, test_Y))
# Out:
# 0.5892857142857143

# %%
from sklearn.ensemble import ExtraTreesClassifier

forest = ExtraTreesClassifier(n_estimators=250, random_state=0)
forest.fit(train_X, train_Y)

importances = forest.feature_importances_
indices = np.argsort(importances)[::-1]

print(forest.score(test_X, test_Y))

# Print the feature ranking
print("Feature ranking:")

for f in range(train_X.shape[1]):
    print("%d. feature %s (%f)" % (f + 1, train_X.columns[indices[f]], importances[indices[f]]))
# Out:
# 0.5739795918367347
# Feature ranking:
# 1. feature B_price (0.088888)
# 2. feature A_price (0.083938)
# 3. feature B_label type_TR (0.023950)
# 4. feature B_label type_MO (0.022201)
# 5. feature B_region_Napa Valley (0.020663)
# 6. feature A_label type_MO (0.020196)
# 7. feature A_label type_TR (0.020034)
# 8. feature B_label type_WH (0.018488)
# 9. feature A_region_Napa Valley (0.018218)
# 10. feature B_varietal_Cabernet Sauvignon (0.015692)
# 11. feature B_region_California (0.015007)
# 12. feature A_varietal_Cabernet Sauvignon (0.014068)
# 13. feature A_region_California (0.013853)
# 14. feature A_label type_WH (0.012499)
# 15. feature A_label type_MI (0.011457)
# 16. feature B_region_Santa Barbara County (0.009640)
# 17. feature B_label type_MI (0.009549)
# 18. feature A_region_Santa Barbara County (0.009350)
# 19. feature B_region_Paso Robles (0.009279)
# 20. feature B_region_Sonoma County (0.009063)
# 21. feature B_region_Sonoma Coast (0.009059)
# ...
