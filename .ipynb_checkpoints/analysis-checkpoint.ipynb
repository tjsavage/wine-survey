# %%
from django_pandas.io import read_frame
import pandas as pd
import matplotlib
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

import os
os.environ['DJANGO_SETTINGS_MODULE'] = 'winesurvey.settings'
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

import django
django.setup()

from survey.models import WineItem, SurveyQuestionResponse, SurveyABTestInstance

# %%
from elosports.elo import Elo
eloLeague = Elo(k = 20, homefield=0)

wine_items = WineItem.objects.all()

for wi in wine_items:
    eloLeague.addPlayer(wi.item_key)

ab_responses = SurveyABTestInstance.objects.all()

for ab in ab_responses:
    eloLeague.gameOver(winner=ab.winner.item_key, loser=ab.loser.item_key, winnerHome=False)

wrs = pd.DataFrame(columns = ['item_key', 'elo', 'price'])
for team in eloLeague.ratingDict.keys():
    wi = WineItem.objects.get(item_key=team)
    row = {'item_key': team, 'price': wi.price, 'elo': eloLeague.ratingDict[team]}
    wrs = wrs.append(row, ignore_index=True)
wrs.sort_values(by='elo')

wrs.plot.scatter(x='elo', y='price')
lr = LinearRegression()
X = wrs['price'].to_numpy().reshape(-1, 1)
Y = wrs['elo'].to_numpy().reshape(-1, 1)
lr.fit(X,Y)
lr.coef_
# Out:
# array([[0.05268519]])

# %%
qs = SurveyQuestionResponse.objects.all()
df = read_frame(qs)

df.pivot(index='survey_response',columns='survey_question',values='answer')
# Out:
# survey_question                                    age bottles_per_month  \
# survey_response
# 2020-05-01 22:47:13.349897+00:00 taylorsavage@g...   2                 5
# 2020-05-06 01:42:51.008991+00:00 test@641.com       15                 3
# 2020-05-06 04:06:19.168595+00:00 test@905.com        1                 6
# 2020-05-17 17:37:39.928605+00:00 test@1036.com      23                56
#
# survey_question                                    buying_location[club_membership]  \
# survey_response
# 2020-05-01 22:47:13.349897+00:00 taylorsavage@g...                                2
# 2020-05-06 01:42:51.008991+00:00 test@641.com                                     1
# 2020-05-06 04:06:19.168595+00:00 test@905.com                                     2
# 2020-05-17 17:37:39.928605+00:00 test@1036.com                                    2
#
# survey_question                                    buying_location[grocery]  \
# survey_response
# ...
